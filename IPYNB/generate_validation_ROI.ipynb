# %%
import os
import h5py as h5
from CollectImgStack_validation import *
import warnings
warnings.filterwarnings("ignore")
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: numpy.ndarray size changed, may indicate binary incompatibility. Expected 80 from C header, got 88 from PyObject

# %%
def main(h5path
        ,train_home
        ,hiclip_val
        ,lowclip_val
        ,nuc_clip_low
        ,nuc_clip_high
        ,cyto_clip_low
        ,cyto_clip_high
        ,clahe
        ,xstart
        ,ystart
        ,zstart
        ,ROI_dim
        ,no_of_layer
        ,orient
        ,res
        ):

    filename = h5path
    # savedir = os.getcwd() + os.sep + 'train'
    if not os.path.exists(train_home):
        os.mkdir(train_home)
    savedir = train_home + os.sep + 'train'
    if not os.path.exists(savedir):
        os.mkdir(savedir)

    split = filename.count("/") - 1
    blockname = filename.split("/")[split]
    print(blockname,"[ xyz:",xstart,ystart,zstart,"]")
    print(savedir)

    xstop = xstart + ROI_dim
    xcoords = (xstart, xstop)

    ystop = ystart + ROI_dim
    ycoords = (ystart, ystop)

    zstop = zstart + no_of_layer
    zcoords = (zstart, zstop)

    with h5.File(filename, 'r') as f:
        collectImgStackFused(f,
                        savedir,
                        blockname,
                        zcoords,
                        xcoords,
                        ycoords,
                        orient,
                        CLAHE=clahe,
                        hiclip_val  = hiclip_val,
                        lowclip_val = lowclip_val,
                        nuc_clip_low   = nuc_clip_low,
                        nuc_clip_high  = nuc_clip_high,
                        cyto_clip_low  = cyto_clip_low,
                        cyto_clip_high = cyto_clip_high, 
                        res = res)
    f.close()

# %%
import pandas as pd
import time
fname = "../coords/Validation_ROI/ROI_coords_2023-10-18_PGP_validation_640_2x.csv" #change this
res = 0 # change to 0 if you want 2X ds

df = pd.read_csv(fname)
df = df.dropna(how="all")


for i in range(len(df)):
    print("ROI #", i)
    if i == 0:
        start = time.time()
    elif i == 1:
        print("Time per ROI : ", start-time.time()/60, "min")

    h5path = df["h5path"][i]
    Ab_home = df["Abhome"][i]
    hiclip_val = df["pgp_clipHigh"][i]
    lowclip_val = df["pgp_clipLow"][i]
    nuc_clip_low = df["nuc_clipLow"][i]
    nuc_clip_high = df["nuc_clipHigh"][i]
    cyto_clip_low = df["cyto_clipLow"][i]
    cyto_clip_high = df["cyto_clipHigh"][i]
    if df["pgp_ctehmt_method"][i] == "Rescale":
        clahe = False
    else:
        clahe = True    
    xstart = df["xcoord"][i]
    ystart = df["ycoord"][i]
    zstart = df["zcoord"][i]
    ROI_dim = df["ROIdim"][i]
    no_of_layer = df["No_ofLayers"][i]
    orient = df["orient"][i]

    main(h5path
        ,Ab_home
        ,hiclip_val,lowclip_val
        ,nuc_clip_low,nuc_clip_high
        ,cyto_clip_low,cyto_clip_high
        ,clahe
        ,xstart,ystart,zstart
        ,ROI_dim,no_of_layer
        ,orient
        ,res)
# Out:
# ROI # 0
# OTLS4_NODO_9-6-23_19-068I.1_PGP9.5 [ xyz: 778 3344 144 ]
# W:\ITAS3D_training_data\PGP9.5\validation_640_2x_trilabel_heldout\train
# reading img s01
# W:\ITAS3D_training_data\PGP9.5\validation_640_2x_trilabel_heldout\train\ch0\OTLS4_NODO_9-6-23_19-068I.1_PGP9.5_Xpos_000778_001418_Ypos_003344_003984_stack_000144_000264
# reading img s02
# W:\ITAS3D_training_data\PGP9.5\validation_640_2x_trilabel_heldout\train\ch2\OTLS4_NODO_9-6-23_19-068I.1_PGP9.5_Xpos_000778_001418_Ypos_003344_003984_stack_000144_000264
# reading img s00
# ROI # 1
# Time per ROI :  1678323899.2536097 min
# OTLS4_NODO_9-6-23_19-068I.1_PGP9.5 [ xyz: 6196 822 120 ]
# W:\ITAS3D_training_data\PGP9.5\validation_640_2x_trilabel_heldout\train
# W:\ITAS3D_training_data\PGP9.5\validation_640_2x_trilabel_heldout\train\ch1\OTLS4_NODO_9-6-23_19-068I.1_PGP9.5_Xpos_006196_006836_Ypos_000822_001462_stack_000120_000240
# reading img s01
# W:\ITAS3D_training_data\PGP9.5\validation_640_2x_trilabel_heldout\train\ch0\OTLS4_NODO_9-6-23_19-068I.1_PGP9.5_Xpos_006196_006836_Ypos_000822_001462_stack_000120_000240
# reading img s02
# W:\ITAS3D_training_data\PGP9.5\validation_640_2x_trilabel_heldout\train\ch2\OTLS4_NODO_9-6-23_19-068I.1_PGP9.5_Xpos_006196_006836_Ypos_000822_001462_stack_000120_000240
# reading img s00
# ROI # 2
# OTLS4_NODO_9-12-23_15-071N_R2_PGP9.5 [ xyz: 8284 1006 224 ]
# W:\ITAS3D_training_data\PGP9.5\validation_640_2x_trilabel_heldout\train
# W:\ITAS3D_training_data\PGP9.5\validation_640_2x_trilabel_heldout\train\ch1\OTLS4_NODO_9-12-23_15-071N_R2_PGP9.5_Xpos_008284_008924_Ypos_001006_001646_stack_000224_000288
# reading img s01
# W:\ITAS3D_training_data\PGP9.5\validation_640_2x_trilabel_heldout\train\ch0\OTLS4_NODO_9-12-23_15-071N_R2_PGP9.5_Xpos_008284_008924_Ypos_001006_001646_stack_000224_000288
# reading img s02
# W:\ITAS3D_training_data\PGP9.5\validation_640_2x_trilabel_heldout\train\ch2\OTLS4_NODO_9-12-23_15-071N_R2_PGP9.5_Xpos_008284_008924_Ypos_001006_001646_stack_000224_000288
# reading img s00
# ROI # 3
# OTLS4_NODO_9-12-23_15-071N_R2_PGP9.5 [ xyz: 6100 7274 312 ]
# W:\ITAS3D_training_data\PGP9.5\validation_640_2x_trilabel_heldout\train
# W:\ITAS3D_training_data\PGP9.5\validation_640_2x_trilabel_heldout\train\ch1\OTLS4_NODO_9-12-23_15-071N_R2_PGP9.5_Xpos_006100_006740_Ypos_007274_007914_stack_000312_000344
# reading img s01
# W:\ITAS3D_training_data\PGP9.5\validation_640_2x_trilabel_heldout\train\ch0\OTLS4_NODO_9-12-23_15-071N_R2_PGP9.5_Xpos_006100_006740_Ypos_007274_007914_stack_000312_000344
# reading img s02
# W:\ITAS3D_training_data\PGP9.5\validation_640_2x_trilabel_heldout\train\ch2\OTLS4_NODO_9-12-23_15-071N_R2_PGP9.5_Xpos_006100_006740_Ypos_007274_007914_stack_000312_000344
# reading img s00
# ROI # 4
# OTLS4_NODO_9-12-23_15-071N_R2_PGP9.5 [ xyz: 7782 7378 192 ]
# W:\ITAS3D_training_data\PGP9.5\validation_640_2x_trilabel_heldout\train
# W:\ITAS3D_training_data\PGP9.5\validation_640_2x_trilabel_heldout\train\ch1\OTLS4_NODO_9-12-23_15-071N_R2_PGP9.5_Xpos_007782_008422_Ypos_007378_008018_stack_000192_000328
# reading img s01
# W:\ITAS3D_training_data\PGP9.5\validation_640_2x_trilabel_heldout\train\ch0\OTLS4_NODO_9-12-23_15-071N_R2_PGP9.5_Xpos_007782_008422_Ypos_007378_008018_stack_000192_000328
# reading img s02
# W:\ITAS3D_training_data\PGP9.5\validation_640_2x_trilabel_heldout\train\ch2\OTLS4_NODO_9-12-23_15-071N_R2_PGP9.5_Xpos_007782_008422_Ypos_007378_008018_stack_000192_000328
# reading img s00
